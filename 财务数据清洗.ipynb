# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 财务数据清洗：从第一次公布季报开始，用旁边的值填充之后为0的项
# ## 资产与市盈率有相同的不为0的项

# %%
fin_data = pd.read_csv("fin_data/001914.SZ.csv",usecols=["date","total_assets","bps"])

# %%
fin_data
# Out:
#         date  total_assets  bps
# 0   20190331  1.220239e+10  0.0
# 1   20181231  1.323565e+10  0.0
# 2   20180930  1.730110e+10  0.0
# 3   20180630  1.938007e+10  0.0
# 4   20180331  1.913392e+10  0.0
# 5   20171231  1.911410e+10  0.0
# 6   20170930  1.919108e+10  0.0
# 7   20170630  1.904727e+10  0.0
# 8   20170331  1.980570e+10  0.0
# 9   20161231  2.173319e+10  0.0
# 10  20160930  2.434533e+10  0.0
# 11  20160630  2.349618e+10  0.0
# 12  20160331  2.397867e+10  0.0
# 13  20151231  2.288102e+10  0.0
# 14  20150930  2.255346e+10  0.0
# 15  20150630  2.230940e+10  0.0
# 16  20150331  2.154410e+10  0.0
# 17  20141231  2.006838e+10  0.0
# 18  20140930  2.131894e+10  0.0
# 19  20140630  2.050879e+10  0.0
# 20  20140331  1.939298e+10  0.0
# 21  20131231  1.771805e+10  0.0
# 22  20130930  1.807158e+10  0.0
# 23  20130630  1.734751e+10  0.0
# 24  20130331  1.521049e+10  0.0
# 25  20121231  1.442614e+10  0.0
# 26  20120930  1.382178e+10  0.0
# 27  20120630  1.311909e+10  0.0
# ...

# %%
flag,order= 0,0
for i in range(len(fin_data)):
    i = len(fin_data)-i-1
    if fin_data["total_assets"].tolist()[i] != 0.0:
        flag = i
        break
    else:
        continue
for i in range(len(fin_data)):
    i = len(fin_data)-i-1
    if fin_data["bps"].tolist()[i] != 0.0:
        order = i
        break
    else:
        continue
print(flag)
print(order)
# Out:
# 93
# 0

# %%
flag,order= 0,0
for i in range(len(fin_data)):
    i = len(fin_data)-i-1
    if fin_data["total_assets"].tolist()[i] != 0.0:
        flag = i
        break
    else:
        continue
for i in range(len(fin_data)):
    i = len(fin_data)-i-1
    if fin_data["bps"].tolist()[i] != 0.0:
        order = i
        break
    else:  
        continue
index = min(flag, order)-3
fin_data.total_assets[index+1:]=0
fin_data.bps[index+1:] = 0

for j in fin_data.total_assets.tolist()[:index+1]:
    if j==0.0:
        order = fin_data.total_assets[fin_data.total_assets == j].index.tolist()[0]
        if sum(fin_data.total_assets.tolist()[order:index+1])==0.0:
            fin_data.total_assets[order]=fin_data.total_assets[order-1]
        else:
            for k in fin_data.total_assets.tolist()[order:index+1]:
                if k!=0.0:
                    fin_data.total_assets[order] = k
                    break
                else:
                    continue
    else:
        continue


for j in fin_data.bps.tolist()[:index+1]:
    if j==0.0:
        order = fin_data.bps[fin_data.bps == j].index.tolist()[0]
        if sum(fin_data.bps.tolist()[order:index+1])==0.0:
            fin_data.bps[order]=fin_data.bps[order-1]
        else:
            for k in fin_data.bps.tolist()[order:index+1]:
                if k!=0.0:
                    fin_data.bps[order] = k
                    break
                else:
                    continue
    else:
        continue
# Out:
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
fin_data.to_csv("cleaned_fin_dat")

# %% [markdown]
# ## 建立循环

# %%
b = [1,2]
a = b
a.remove(1)
print(b)
# Out:
# [2]

# %%
code_list.drop([1,2])
# Out:
#         ts_code  list_date
# 0     000001.SZ   19910403
# 3     000005.SZ   19901210
# 4     000006.SZ   19920427
# 5     000007.SZ   19920413
# 6     000008.SZ   19920507
# 7     000009.SZ   19910625
# 8     000010.SZ   19951027
# 9     000011.SZ   19920330
# 10    000012.SZ   19920228
# 11    000014.SZ   19920602
# 12    000016.SZ   19920327
# 13    000017.SZ   19920331
# 14    000019.SZ   19921012
# 15    000020.SZ   19920428
# 16    000021.SZ   19940202
# 17    000023.SZ   19930429
# 18    000025.SZ   19930621
# 19    000026.SZ   19930603
# 20    000027.SZ   19930903
# 21    000028.SZ   19930809
# 22    000029.SZ   19930915
# 23    000030.SZ   19930929
# 24    000031.SZ   19931008
# 25    000032.SZ   19931028
# 26    000034.SZ   19940509
# 27    000035.SZ   19940408
# 28    000036.SZ   19940617
# 29    000037.SZ   19940701
# 30    000038.SZ   19940808
# 31    000039.SZ   19940408
# ...         ...        ...
# 3516  603936.SH   20151209
# 3517  603937.SH   20171102
# ...

# %%
code_list = pd.read_csv("data/code_list.csv",usecols=["ts_code","list_date"])
ls = []
for c in code_list["ts_code"]:
    fin_data = pd.read_csv("fin_data/"+c+".csv",usecols=["date","total_assets","bps"])
    flag,order= 0,0
    for i in range(len(fin_data)):
        i = len(fin_data)-i-1
        if fin_data["total_assets"].tolist()[i] != 0.0:
            flag = i
            break
        else:
            continue
    for i in range(len(fin_data)):
        i = len(fin_data)-i-1
        if fin_data["bps"].tolist()[i] != 0.0:
            order = i
            break
        else:
            continue
    index = min(flag, order)-3
    if index < 2:
        ls.append(code_list[code_list.ts_code == c].index.tolist()[0])
        print("kick out:"+c)
        continue
    fin_data.total_assets[index+1:]=0
    fin_data.bps[index+1:] = 0
    for j in fin_data.total_assets.tolist()[:index+1]:
        if j==0.0:
            order = fin_data.total_assets[fin_data.total_assets == j].index.tolist()[0]
            if sum(fin_data.total_assets.tolist()[order:index+1])==0.0:
                fin_data.total_assets[order]=fin_data.total_assets[order-1]
            else:
                for k in fin_data.total_assets.tolist()[order:index+1]:
                    if k!=0.0:
                        fin_data.total_assets[order] = k
                        break
                    else:
                        continue
        else:
            continue

    for j in fin_data.bps.tolist()[:index+1]:
        if j==0.0:
            order = fin_data.bps[fin_data.bps == j].index.tolist()[0]
            if sum(fin_data.bps.tolist()[order:index+1])==0.0:
                fin_data.bps[order]=fin_data.bps[order-1]
            else:
                for k in fin_data.bps.tolist()[order:index+1]:
                    if k!=0.0:
                        fin_data.bps[order] = k
                        break
                    else:
                        continue
        else:
            continue
    fin_data.to_csv("cleaned_fin_data/"+c+".csv")
    print(c)
code_list.drop(ls,axis=0,inplace=True) 
code_list.to_csv("cleaned_fin_data/cleaned_code_list.csv")
# Out:
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## 由于前面计算错误，需要错算得到的一本比率，取倒数，得到季度市盈率，乘以0.25，得到年度市盈率

# %%
code_list = pd.read_csv("cleaned_fin_data/cleaned_code_list.csv",usecols=["ts_code","list_date"])

# %%
code_list
# Out:
#         ts_code  list_date
# 0     000001.SZ   19910403
# 1     000002.SZ   19910129
# 2     000004.SZ   19910114
# 3     000005.SZ   19901210
# 4     000006.SZ   19920427
# 5     000007.SZ   19920413
# 6     000008.SZ   19920507
# 7     000009.SZ   19910625
# 8     000010.SZ   19951027
# 9     000011.SZ   19920330
# 10    000012.SZ   19920228
# 11    000014.SZ   19920602
# 12    000016.SZ   19920327
# 13    000017.SZ   19920331
# 14    000019.SZ   19921012
# 15    000020.SZ   19920428
# 16    000021.SZ   19940202
# 17    000023.SZ   19930429
# 18    000025.SZ   19930621
# 19    000026.SZ   19930603
# 20    000027.SZ   19930903
# 21    000028.SZ   19930809
# 22    000029.SZ   19930915
# 23    000030.SZ   19930929
# 24    000031.SZ   19931008
# 25    000032.SZ   19931028
# 26    000034.SZ   19940509
# 27    000035.SZ   19940408
# 28    000036.SZ   19940617
# 29    000037.SZ   19940701
# ...         ...        ...
# 3410  603936.SH   20151209
# 3411  603937.SH   20171102
# ...

# %%
c = code_list["ts_code"][5]

# %%
c
# Out:
# '000007.SZ'

# %%
cleaned_fin_data = pd.read_csv("cleaned_fin_data/"+c+".csv",usecols=["date","total_assets","bps"])

# %%
cleaned_fin_data
# Out:
#         date  total_assets       bps
# 0   20190331  3.962312e+08  3.199097
# 1   20181231  3.857100e+08  3.693233
# 2   20180930  4.253263e+08  2.542819
# 3   20180630  4.259043e+08  3.119527
# 4   20180331  4.294605e+08  3.291457
# 5   20171231  4.426756e+08  3.573963
# 6   20170930  4.314219e+08  3.573963
# 7   20170630  4.462191e+08  3.938591
# 8   20170331  4.852911e+08  3.938591
# 9   20161231  5.143677e+08  3.938591
# 10  20160930  5.575805e+08  3.389958
# 11  20160630  5.755976e+08  3.467704
# 12  20160331  5.580976e+08  3.467704
# 13  20151231  4.803645e+08  3.467704
# 14  20150930  5.268040e+08  2.675330
# 15  20150630  5.260907e+08  2.675330
# 16  20150331  6.700289e+08  2.675330
# 17  20141231  6.809252e+08  2.370493
# 18  20140930  6.661728e+08  2.541605
# 19  20140630  6.853959e+08  2.087551
# 20  20140331  6.938626e+08  2.087551
# 21  20131231  6.575119e+08  2.213273
# 22  20130930  5.850099e+08  2.722382
# 23  20130630  5.919229e+08  4.173699
# ...

# %%
cleaned_fin_data.bps = 1/(cleaned_fin_data.bps*4)

# %%
cleaned_fin_data.bps[cleaned_fin_data.bps[cleaned_fin_data.bps==float("inf")].index.tolist()]=0.0
# Out:
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
code_list = pd.read_csv("cleaned_fin_data/cleaned_code_list.csv",usecols=["ts_code","list_date"])
for c in code_list["ts_code"]:
    cleaned_fin_data = pd.read_csv("cleaned_fin_data/"+c+".csv",usecols=["date","total_assets","bps"])
    cleaned_fin_data.bps = 1/(cleaned_fin_data.bps*4)
    cleaned_fin_data.bps[cleaned_fin_data.bps[cleaned_fin_data.bps==float("inf")].index.tolist()]=0.0
    cleaned_fin_data.to_csv("cleaned_fin_data/"+c+".csv")
    print(c)
# Out:
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 000001.SZ
# 000002.SZ
# 000004.SZ
# 000005.SZ
# 000006.SZ
# 000007.SZ
# 000008.SZ
# 000009.SZ
# 000010.SZ
# 000011.SZ
# 000012.SZ
# 000014.SZ
# 000016.SZ
# 000017.SZ
# 000019.SZ
# 000020.SZ
# 000021.SZ
# 000023.SZ
# 000025.SZ
# 000026.SZ
# 000027.SZ
# 000028.SZ
# 000029.SZ
# 000030.SZ
# 000031.SZ
# 000032.SZ
# 000034.SZ
# 000035.SZ
# 000036.SZ
# 000037.SZ
# 000038.SZ
# 000039.SZ
# 000040.SZ
# 000042.SZ
# 000045.SZ
# 000046.SZ
# 000048.SZ
# 000049.SZ
# 000050.SZ
# 000055.SZ
# 000056.SZ
# 000058.SZ
# 000059.SZ
# 000060.SZ
# 000061.SZ
# 000062.SZ
# 000063.SZ
# 000065.SZ
# 000066.SZ
# 000068.SZ
# 000069.SZ
# 000070.SZ
# 000078.SZ
# 000088.SZ
# 000089.SZ
# 000090.SZ
# 000096.SZ
# 000099.SZ
# ...

# %% [markdown]
# # 以下为历史版本

# %% [markdown]
# ## 清洗总资产数据

# %%
fin_data
# Out:
#         date  total_assets       bps
# 0   20190331  1.551166e+12  0.495834
# 1   20181231  1.528579e+12  0.565143
# 2   20180930  1.432222e+12  0.524984
# 3   20180630  1.345152e+12  0.457999
# 4   20180331  1.224265e+12  0.379051
# 5   20171231  1.165347e+12  0.399103
# 6   20170930  1.018382e+12  0.399224
# 7   20170630  9.292659e+11  0.456337
# 8   20170331  8.867535e+11  0.494411
# 9   20161231  8.306742e+11  0.448486
# 10  20160930  7.559296e+11  0.372235
# 11  20160630  7.123067e+11       inf
# 12  20160331  6.588375e+11       inf
# 13  20151231  6.112956e+11  0.429558
# 14  20150930  5.707934e+11  0.605652
# 15  20150630  5.369376e+11  0.544505
# 16  20150331  5.260404e+11  0.635294
# 17  20141231  5.084088e+11  0.662220
# 18  20140930  5.199741e+11  0.757331
# 19  20140630  5.017743e+11  0.842777
# 20  20140331  4.951190e+11  0.863459
# 21  20131231  4.792053e+11  0.843880
# 22  20130930  4.611378e+11  0.652242
# 23  20130630  4.322420e+11  0.581138
# ...

# %%
if fin_data.date.tolist()[0]<fin_data.date.tolist()[1]:
    for i in range(len(fin_data)):
        if fin_data["total_assets"].tolist()[i] != 0.0:
            for j in fin_data.total_assets.tolist()[i:]:
                if j==0.0:
                    order = fin_data.total_assets[fin_data.total_assets == j].index.tolist()[0]
                    for k in fin_data.total_assets.tolist()[order+1:i+1]:
                        if k!=0.0:
                            fin_data.total_assets[order] = k
                            break
                        else:
                            continue
                else:
                    continue
            break
        else:
            continue
else:
    for i in range(len(fin_data)):
        i = len(fin_data)-i-1
        if fin_data["total_assets"].tolist()[i] != 0.0:
            for j in fin_data.total_assets.tolist()[:i+1]:
                if j==0.0:
                    order = fin_data.total_assets[fin_data.total_assets == j].index.tolist()[0]
                    for k in fin_data.total_assets.tolist()[order:i+1]:
                        if k!=0.0:
                            fin_data.total_assets[order] = k
                            break
                        else:
                            continue
                else:
                    continue
            break
        else:
            continue
# Out:
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## 清洗市盈率数据

# %%
if fin_data.date.tolist()[0]<fin_data.date.tolist()[1]:
    for i in range(len(fin_data)):
        if fin_data["bps"].tolist()[i] != 0.0:
            for j in fin_data.bps.tolist()[i:]:
                if j==0.0:
                    order = fin_data.bps[fin_data.bps == j].index.tolist()[0]
                    for k in fin_data.bps.tolist()[order:i+1]:
                        if k!=0.0:
                            fin_data.bps[order] = k
                            break
                        else:
                            continue
                else:
                    continue
            break
        else:
            continue
else:
    for i in range(len(fin_data)):
        i = len(fin_data)-i-1
        if fin_data["bps"].tolist()[i] != 0.0:
            for j in fin_data.bps.tolist()[:i]:
                if j==0.0:
                    order = fin_data.bps[fin_data.bps == j].index.tolist()[0]
                    for k in fin_data.bps.tolist()[order:i+1]:
                        if k!=0.0:
                            fin_data.bps[order] = k
                            break
                        else:
                            continue
                else:
                    continue
            break
        else:
            continue
# Out:
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## 将清洗后的数据写入文件

# %%
fin_data.to_csv("test.csv")

# %% [markdown]
# ## 建立循环

# %%
code_list = pd.read_csv("data/code_list.csv",usecols=["ts_code","list_date"])
for c in code_list["ts_code"]:
    fin_data = pd.read_csv("fin_data/"+c+".csv",usecols=["date","total_assets","bps"])
    if fin_data.date.tolist()[0]<fin_data.date.tolist()[1]:
        for i in range(len(fin_data)):
            if fin_data["total_assets"].tolist()[i] != 0.0:
                for j in fin_data.total_assets.tolist()[i:]:
                    if j==0.0:
                        order = fin_data.total_assets[fin_data.total_assets == j].index.tolist()[0]
                        for k in fin_data.total_assets.tolist()[order+1:i+1]:
                            if k!=0.0:
                                fin_data.total_assets[order] = k
                                break
                            else:
                                continue
                    else:
                        continue
                break
            else:
                continue
    else:
        for i in range(len(fin_data)):
            i = len(fin_data)-i-1
            if fin_data["total_assets"].tolist()[i] != 0.0:
                for j in fin_data.total_assets.tolist()[:i+1]:
                    if j==0.0:
                        order = fin_data.total_assets[fin_data.total_assets == j].index.tolist()[0]
                        for k in fin_data.total_assets.tolist()[order:i+1]:
                            if k!=0.0:
                                fin_data.total_assets[order] = k
                                break
                            else:
                                continue
                    else:
                        continue
                break
            else:
                continue
                
    fin_data.to_csv("fin_data/"+c+".csv")
    print(c)
# Out:
# 000001.SZ
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 000002.SZ
# 000004.SZ
# 000005.SZ
# 000006.SZ
# 000007.SZ
# 000008.SZ
# 000009.SZ
# 000010.SZ
# 000011.SZ
# 000012.SZ
# 000014.SZ
# 000016.SZ
# 000017.SZ
# 000019.SZ
# 000020.SZ
# 000021.SZ
# 000023.SZ
# 000025.SZ
# 000026.SZ
# 000027.SZ
# 000028.SZ
# 000029.SZ
# 000030.SZ
# 000031.SZ
# 000032.SZ
# 000034.SZ
# 000035.SZ
# 000036.SZ
# 000037.SZ
# 000038.SZ
# 000039.SZ
# 000040.SZ
# 000042.SZ
# 000045.SZ
# 000046.SZ
# 000048.SZ
# 000049.SZ
# 000050.SZ
# 000055.SZ
# 000056.SZ
# 000058.SZ
# 000059.SZ
# 000060.SZ
# 000061.SZ
# 000062.SZ
# 000063.SZ
# 000065.SZ
# 000066.SZ
# 000068.SZ
# 000069.SZ
# 000070.SZ
# 000078.SZ
# 000088.SZ
# 000089.SZ
# 000090.SZ
# 000096.SZ
# 000099.SZ
# 000100.SZ
# ...

# %%
code_list = pd.read_csv("data/code_list.csv",usecols=["ts_code","list_date"])
for c in code_list["ts_code"]:
    if fin_data.date.tolist()[0]<fin_data.date.tolist()[1]:
        for i in range(len(fin_data)):
            if fin_data["bps"].tolist()[i] != 0.0:
                for j in fin_data.bps.tolist()[i:]:
                    if j==0.0:
                        order = fin_data.bps[fin_data.bps == j].index.tolist()[0]
                        for k in fin_data.bps.tolist()[order:i+1]:
                            if k!=0.0:
                                fin_data.bps[order] = k
                                break
                            else:
                                continue
                    else:
                        continue
                break
            else:
                continue
    else:
        for i in range(len(fin_data)):
            i = len(fin_data)-i-1
            if fin_data["bps"].tolist()[i] != 0.0:
                for j in fin_data.bps.tolist()[:i]:
                    if j==0.0:
                        order = fin_data.bps[fin_data.bps == j].index.tolist()[0]
                        for k in fin_data.bps.tolist()[order:i+1]:
                            if k!=0.0:
                                fin_data.bps[order] = k
                                break
                            else:
                                continue
                    else:
                        continue
                break
            else:
                continue
        fin_data.to_csv("fin_data/"+c+".csv")
        print(c)
# Out:
# D:\softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 000001.SZ
# 000002.SZ
# 000004.SZ
# 000005.SZ
# 000006.SZ
# 000007.SZ
# 000008.SZ
# 000009.SZ
# 000010.SZ
# 000011.SZ
# 000012.SZ
# 000014.SZ
# 000016.SZ
# 000017.SZ
# 000019.SZ
# 000020.SZ
# 000021.SZ
# 000023.SZ
# 000025.SZ
# 000026.SZ
# 000027.SZ
# 000028.SZ
# 000029.SZ
# 000030.SZ
# 000031.SZ
# 000032.SZ
# 000034.SZ
# 000035.SZ
# 000036.SZ
# 000037.SZ
# 000038.SZ
# 000039.SZ
# 000040.SZ
# 000042.SZ
# 000045.SZ
# 000046.SZ
# 000048.SZ
# 000049.SZ
# 000050.SZ
# 000055.SZ
# 000056.SZ
# 000058.SZ
# 000059.SZ
# 000060.SZ
# 000061.SZ
# 000062.SZ
# 000063.SZ
# 000065.SZ
# 000066.SZ
# 000068.SZ
# 000069.SZ
# 000070.SZ
# 000078.SZ
# 000088.SZ
# 000089.SZ
# 000090.SZ
# 000096.SZ
# 000099.SZ
# 000100.SZ
# ...

# %%
1/(float("inf"))
# Out:
# 0.0
