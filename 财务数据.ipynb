# %%
import tushare as ts
import pandas as pd
import numpy as np

# %%
pro = ts.pro_api()

# %%
date = []
for i in range(94):
    temp = ""
    temp += str(2018-(i-1)//4)
    month = str((4-(i-1)%4)*3)
    if month == "6" :
        day = "30"
    elif  month == "9":
        day ="30"
    else:
        day = "31"
    temp += "{:0>2}".format(month)
    temp += day
    date.append(temp)
# Out:
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12
# 9
# 6
# 3
# 12

# %%
n = 3037
for p in code_list["ts_code"].tolist()[n:]:
    asset = pro.balancesheet(ts_code=p, start_date='19951201', end_date='20190431', fields='end_date,total_assets')
    ls1 = mother.index.tolist()
    ls2 = asset.end_date.tolist()
    for i in ls1:
        s = ls2.count(i)
        if s>1:
            asset.drop(asset[asset.end_date == i].index.tolist()[0],axis=0,inplace=True)
    asset.index = asset["end_date"].tolist()
    asset.drop("end_date",axis=1,inplace=True)


    fin_data = mother.join(asset).fillna(0)

    bps = pro.fina_indicator(ts_code=p,start_date='19951201', end_date='20190431')
    temp = pd.DataFrame({"bps":bps["bps"].tolist()},index=bps["end_date"].tolist())
    price = pd.read_csv('trade_data/'+p+'.csv',usecols=["trade_date","close"])
    ls = []
    for k in range(len(temp)):

        s = 0.0
        count = 0
        times = 0
        for i in price["trade_date"]:
            if str(i)[:6]==temp.index.tolist()[k][:6]:
                j = temp.index.tolist()[k][:6]
                while j == temp.index.tolist()[k][:6]:
                    s += price["close"][count]
                    times += 1
                    count += 1
                    if count >len(price)-1:
                        break
                    j = str(price["trade_date"][count])[:6]
                break
            count += 1
        if times == 0:
            ls.append(float("inf"))
        else:
            ls.append(s/times)



    temp.bps=ls/temp.bps
    temp.rename(columns={"bps":"pe"})
    fin_data = fin_data.join(temp).fillna(0)

    fin_data.to_csv('fin_data/'+p+'.csv')
    n += 1
    print("{:<11}".format(p),end="  ")
    print("{:<11}".format(n),end="  ")
# Out:
# 601700.SH    3038         601717.SH    3039         601718.SH    3040         601727.SH    3041         601766.SH    3042         601777.SH    3043         601788.SH    3044         601789.SH    3045         601798.SH    3046         601799.SH    3047         601800.SH    3048         601801.SH    3049         601808.SH    3050         601811.SH    3051         601818.SH    3052         601828.SH    3053         601838.SH    3054         601857.SH    3055         601858.SH    3056         601866.SH    3057         601869.SH    3058         601872.SH    3059         601877.SH    3060         601878.SH    3061         601880.SH    3062         601881.SH    3063         601882.SH    3064         601886.SH    3065         601888.SH    3066         601890.SH    3067         601898.SH    3068         601899.SH    3069         601900.SH    3070         601901.SH    3071         601908.SH    3072         601918.SH    3073         601919.SH    3074         601928.SH    3075         601929.SH 
# ...

# %%
bps = pro.fina_indicator(ts_code="001914.SZ",start_date='19951201', end_date='20190431')
temp = pd.DataFrame({"bps":bps["bps"].tolist()},index=bps["end_date"].tolist())

# %%
temp
# Out:
#              bps
# 20190331  7.3407
# 20181231  7.2598
# 20180930  7.4145
# 20180630  6.3594
# 20180331  6.3738
# 20171231  6.2649
# 20170930  5.9385
# 20170630  5.8371
# 20170331  6.0047
# 20161231  6.1212
# 20160930  5.8387
# 20160630  5.8847
# 20160331  5.6973
# 20151231  5.9339
# 20150930  4.8998
# 20150630  4.9882
# 20150331  5.1547
# 20141231  5.2587
# 20140930  4.4238
# 20140630  4.6192
# 20140331  4.9316
# 20131231  4.8602
# 20130930  4.2905
# 20130630  4.2040
# 20130331  4.2954
# 20121231  4.3781
# 20120930  4.1029
# 20120630  3.8183
# 20120331  7.7607
# 20111231  7.7832
# ...          ...
# 20060331  2.7359
# 20051231  2.6700
# 20050930  2.3600
# 20050630  2.3100
# 20050331  2.3800
# 20041231  2.3400
# 20040930  2.2400
# 20040630  2.2400
# 20040331  2.2100
# 20031231  2.1700
# 20030930  2.0700
# 20030630  2.0100
# 20030331  2.0100
# 20021231  1.9800
# 20020930  1.9980
# 20020630  1.8620
# 20020331  1.8483
# 20011231  1.8200
# 20010630  2.9600
# 20001231  3.1400
# ...
